# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Salary_dataset.csv')
x = df.iloc[:, :-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
for i,j in enumerate(df['YearsExperience']):
    df['YearsExperience'][i]=math.floor(j*10)/10
    # print(i,j)
df['YearsExperience']
# Out:
# 0      1.2
# 1      1.4
# 2      1.6
# 3      2.1
# 4      2.3
# 5      3.0
# 6      3.1
# 7      3.3
# 8      3.3
# 9      3.8
# 10     4.0
# 11     4.1
# 12     4.1
# 13     4.1
# 14     4.6
# 15     5.0
# 16     5.1
# 17     5.4
# 18     6.0
# 19     6.1
# 20     6.9
# 21     7.2
# 22     8.0
# 23     8.2
# 24     8.7
# 25     9.1
# 26     9.6
# 27     9.7
# 28    10.4
# 29    10.6
# Name: YearsExperience, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
regrassor = LinearRegression()
regrassor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
len(y_train)
# Out:
# 21

# %%
y_pred = regrassor.predict(x_test)
y_pred
# Out:
# array([ 41068.96469651, 124994.63666745,  63523.55124173,  63316.24056634,
#        117108.4126212 , 109222.18857494, 117564.91702613,  63772.74497127,
#         74647.18917665])

# %%
y_train
# Out:
# 22    101303.0
# 5      56643.0
# 16     66030.0
# 8      64446.0
# 14     61112.0
# 23    113813.0
# 20     91739.0
# 1      46206.0
# 29    121873.0
# 6      60151.0
# 4      39892.0
# 18     81364.0
# 19     93941.0
# 9      57190.0
# 7      54446.0
# 25    105583.0
# 3      43526.0
# 0      39344.0
# 21     98274.0
# 15     67939.0
# 12     56958.0
# Name: Salary, dtype: float64

# %%
plt.hist(x_train)
# Out:
# (array([[2., 3., 3., 1., 2., 2., 3., 3., 1., 1.],
#         [4., 9., 6., 2., 0., 0., 0., 0., 0., 0.]]),
#  array([ 0. ,  2.9,  5.8,  8.7, 11.6, 14.5, 17.4, 20.3, 23.2, 26.1, 29. ]),
#  <a list of 2 BarContainer objects>)

# %%
plt.hist(y_train)
# Out:
# (array([4., 1., 5., 3., 0., 1., 2., 2., 1., 2.]),
#  array([ 39344. ,  47596.9,  55849.8,  64102.7,  72355.6,  80608.5,
#          88861.4,  97114.3, 105367.2, 113620.1, 121873. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(x_train['YearsExperience'],y_train)
