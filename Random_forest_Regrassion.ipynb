# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Position_Salaries.csv')
x = dataset.iloc[: , 1:-1].values
y = dataset.iloc[: , -1].values

# %%
from sklearn.ensemble import RandomForestRegressor
regrassor = RandomForestRegressor(n_estimators=10,random_state=0)
regrassor.fit(x,y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
regrassor.predict([[6.5]])
# Out:
# array([167000.])

# %%
regrassor.predict([[7]])
# Out:
# array([210000.])

# %%
x_grid = np.arange(min(x), max(x), 0.1)  # Use max(x) as the end of range
x_grid = x_grid.reshape(len(x_grid), 1)
plt.scatter(x, y, color='red')
plt.plot(x_grid, regrassor.predict(x_grid), color='blue')
plt.title('Truth or Bluff (Random forest Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\AMLAN PATRA\AppData\Local\Temp\ipykernel_14852\3204978129.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(x), max(x), 0.1)  # Use max(x) as the end of range
