# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Position_Salaries.csv')
x = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
print(y)
# Out:
# [  45000   50000   60000   80000  110000  150000  200000  300000  500000
#  1000000]

# %%
from sklearn.tree import DecisionTreeRegressor
regrassor = DecisionTreeRegressor(random_state=0)
regrassor.fit(x,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
regrassor.predict([[6.5]])
# Out:
# array([150000.])

# %%
x_grid = np.arange(min(x), max(x), 0.1)  # Use max(x) as the end of range
x_grid = x_grid.reshape(len(x_grid), 1)
plt.scatter(x, y, color='red')
plt.plot(x_grid, regrassor.predict(x_grid), color='blue')
plt.title('Truth or Bluff (Decision Tree Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\AMLAN PATRA\AppData\Local\Temp\ipykernel_10632\2018114032.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(x), max(x), 0.1)  # Use max(x) as the end of range
